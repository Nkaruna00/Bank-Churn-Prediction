# %%
jupyter notebook --notebook-dir=D:/

# %%
pip install pandas

# %%
pip install scikit-learn

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in e:\logiciel\anaconda\envs\work\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in e:\logiciel\anaconda\envs\work\lib\site-packages (from seaborn) (2.1.2)
# Collecting matplotlib!=3.6.1,>=3.3 (from seaborn)
#   Downloading matplotlib-3.8.0-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading contourpy-1.1.1-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading fonttools-4.43.1-cp310-cp310-win_amd64.whl.metadata (155 kB)
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      ------------------------------ ------- 122.9/155.5 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 155.5/155.5 kB 2.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in e:\logiciel\anaconda\envs\work\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Collecting pillow>=6.2.0 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading Pillow-10.1.0-cp310-cp310-win_amd64.whl.metadata (9.6 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in e:\logiciel\anaconda\envs\work\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\logiciel\anaconda\envs\work\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\logiciel\anaconda\envs\work\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in e:\logiciel\anaconda\envs\work\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    ---------------------------------------- 294.6/294.6 kB 9.2 MB/s eta 0:00:00
# Downloading matplotlib-3.8.0-cp310-cp310-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.6 MB 17.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.6 MB 21.8 MB/s eta 0:00:01
#    -------------------- ------------------- 3.9/7.6 MB 27.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.4/7.6 MB 39.4 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 37.6 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 37.6 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 37.6 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 37.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 19.6 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp310-cp310-win_amd64.whl (477 kB)
#    ---------------------------------------- 0.0/478.0 kB ? eta -:--:--
#    --------------------------------------- 478.0/478.0 kB 29.2 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.43.1-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------  2.1/2.1 MB 68.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 27.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 3.1 MB/s eta 0:00:00
# Downloading Pillow-10.1.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------  2.6/2.6 MB 83.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 27.6 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ---------------------------------------- 103.1/103.1 kB ? eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.1.0 pyparsing-3.1.1 seaborn-0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in e:\logiciel\anaconda\envs\work\lib\site-packages (1.26.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Packages

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Dataset Importation

# %%
bank_dataset = pd.read_csv("../Datasets/Churn_Modelling.csv")

# %%
bank_dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
churn_calc = bank_dataset.drop(["RowNumber", "CustomerId", "Surname"], axis = 1)

# %%
churn_calc.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
churn_calc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %%
churn_calc.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
churn_calc.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
churn_encod = pd.get_dummies(churn_calc)

# %%
churn_encod
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0                  1        101348.88       1              True
# 1                  1        112542.58       0             False
# 2                  0        113931.57       1              True
# 3                  0         93826.63       0              True
# 4                  1         79084.10       0             False
# ...              ...              ...     ...               ...
# 9995               0         96270.64       0              True
# 9996               1        101699.77       0              True
# 9997               1         42085.58       1              True
# 9998               0         92888.52       1             False
# 9999               0         38190.78       0              True
#
#       Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# 0                 False            False           True        False
# 1                 False             True           True        False
# 2                 False            False           True        False
# 3                 False            False           True        False
# 4                 False             True           True        False
# ...                 ...              ...            ...          ...
# 9995              False            False          False         True
# 9996              False            False          False         True
# 9997              False            False           True        False
# 9998               True            False          False         True
# 9999              False            False           True        False
#
# [10000 rows x 14 columns]

# %%
churn_encod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        10000 non-null  int64
#  1   Age                10000 non-null  int64
#  2   Tenure             10000 non-null  int64
#  3   Balance            10000 non-null  float64
#  4   NumOfProducts      10000 non-null  int64
#  5   HasCrCard          10000 non-null  int64
#  6   IsActiveMember     10000 non-null  int64
#  7   EstimatedSalary    10000 non-null  float64
#  8   Exited             10000 non-null  int64
#  9   Geography_France   10000 non-null  bool
#  10  Geography_Germany  10000 non-null  bool
#  11  Geography_Spain    10000 non-null  bool
#  12  Gender_Female      10000 non-null  bool
#  13  Gender_Male        10000 non-null  bool
# dtypes: bool(5), float64(2), int64(7)
# memory usage: 752.1 KB

# %%
scaler = MinMaxScaler()

# %%
churn_encod[['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary']] = scaler.fit_transform(churn_encod[['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary']])

# %%
churn_encod
# Out:
#       CreditScore       Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0           0.538  0.324324     0.2  0.000000       0.000000          1
# 1           0.516  0.310811     0.1  0.334031       0.000000          0
# 2           0.304  0.324324     0.8  0.636357       0.666667          1
# 3           0.698  0.283784     0.1  0.000000       0.333333          0
# 4           1.000  0.337838     0.2  0.500246       0.000000          1
# ...           ...       ...     ...       ...            ...        ...
# 9995        0.842  0.283784     0.5  0.000000       0.333333          1
# 9996        0.332  0.229730     1.0  0.228657       0.000000          1
# 9997        0.718  0.243243     0.7  0.000000       0.000000          0
# 9998        0.844  0.324324     0.3  0.299226       0.333333          1
# 9999        0.884  0.135135     0.4  0.518708       0.000000          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0                  1         0.506735       1              True
# 1                  1         0.562709       0             False
# 2                  0         0.569654       1              True
# 3                  0         0.469120       0              True
# 4                  1         0.395400       0             False
# ...              ...              ...     ...               ...
# 9995               0         0.481341       0              True
# 9996               1         0.508490       0              True
# 9997               1         0.210390       1              True
# 9998               0         0.464429       1             False
# 9999               0         0.190914       0              True
#
#       Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# 0                 False            False           True        False
# 1                 False             True           True        False
# 2                 False            False           True        False
# 3                 False            False           True        False
# 4                 False             True           True        False
# ...                 ...              ...            ...          ...
# 9995              False            False          False         True
# 9996              False            False          False         True
# 9997              False            False           True        False
# 9998               True            False          False         True
# 9999              False            False           True        False
#
# [10000 rows x 14 columns]

# %%
churn_encod[["CreditScore","Age"]]
# Out:
#       CreditScore       Age
# 0           0.538  0.324324
# 1           0.516  0.310811
# 2           0.304  0.324324
# 3           0.698  0.283784
# 4           1.000  0.337838
# ...           ...       ...
# 9995        0.842  0.283784
# 9996        0.332  0.229730
# 9997        0.718  0.243243
# 9998        0.844  0.324324
# 9999        0.884  0.135135
#
# [10000 rows x 2 columns]

# %%
corr = churn_encod.corr()
corr.shape
# Out:
# (14, 14)

# %%
plt.figure(figsize = (50,50))

# %%
sns.heatmap(corr, cbar=True, square= True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap='YlGnBu',linewidths=.5)
# Out:
# <Axes: >
